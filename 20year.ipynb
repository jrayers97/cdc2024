# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_excel("Business_Dataset.xlsx",engine='openpyxl')
df
# Out:
#             tbl  Year  quarter  citymarketid_1  citymarketid_2  \
# 0       Table1a  2021        3           30135           33195
# 1       Table1a  2021        3           30135           33195
# 2       Table1a  2021        3           30140           30194
# 3       Table1a  2021        3           30140           30194
# 4       Table1a  2021        3           30140           30466
# ...         ...   ...      ...             ...             ...
# 245950  Table1a  2024        1           35412           31703
# 245951  Table1a  2024        1           35412           32467
# 245952  Table1a  2024        1           35412           32467
# 245953  Table1a  2024        1           35412           33195
# 245954  Table1a  2024        1           35412           33195
#
#                                  city1                                  city2  \
# 0       Allentown/Bethlehem/Easton, PA          Tampa, FL (Metropolitan Area)
# ...

# %%
df.head()
# Out:
#        tbl  Year  quarter  citymarketid_1  citymarketid_2  \
# 0  Table1a  2021        3           30135           33195
# 1  Table1a  2021        3           30135           33195
# 2  Table1a  2021        3           30140           30194
# 3  Table1a  2021        3           30140           30194
# 4  Table1a  2021        3           30140           30466
#
#                             city1                          city2  airportid_1  \
# 0  Allentown/Bethlehem/Easton, PA  Tampa, FL (Metropolitan Area)        10135
# 1  Allentown/Bethlehem/Easton, PA  Tampa, FL (Metropolitan Area)        10135
# 2                 Albuquerque, NM          Dallas/Fort Worth, TX        10140
# 3                 Albuquerque, NM          Dallas/Fort Worth, TX        10140
# 4                 Albuquerque, NM                    Phoenix, AZ        10140
#
#    airportid_2 airport_1  ...    fare  carrier_lg  large_ms  fare_lg  \
# 0        14112       ABE  ...   81.43          G4    1.0000    81.43
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245955 entries, 0 to 245954
# Data columns (total 23 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tbl             245955 non-null  object
#  1   Year            245955 non-null  int64
#  2   quarter         245955 non-null  int64
#  3   citymarketid_1  245955 non-null  int64
#  4   citymarketid_2  245955 non-null  int64
#  5   city1           245955 non-null  object
#  6   city2           245955 non-null  object
#  7   airportid_1     245955 non-null  int64
#  8   airportid_2     245955 non-null  int64
#  9   airport_1       245955 non-null  object
#  10  airport_2       245955 non-null  object
#  11  nsmiles         245955 non-null  int64
#  12  passengers      245955 non-null  int64
#  13  fare            245955 non-null  float64
#  14  carrier_lg      244415 non-null  object
#  15  large_ms        244415 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Year        quarter  citymarketid_1  citymarketid_2  \
# count  245955.000000  245955.000000   245955.000000   245955.000000
# mean     2008.524124       2.479153    31556.430201    32180.117086
# std         8.703364       1.122149     1089.872880     1232.464184
# min      1993.000000       1.000000    30135.000000    30189.000000
# 25%      2001.000000       1.000000    30721.000000    30994.000000
# 50%      2008.000000       2.000000    31423.000000    32211.000000
# 75%      2016.000000       3.000000    32467.000000    33192.000000
# max      2024.000000       4.000000    35412.000000    35628.000000
#
#          airportid_1    airportid_2        nsmiles     passengers  \
# count  245955.000000  245955.000000  245955.000000  245955.000000
# mean    12437.099986   13249.889525    1189.812319     299.476795
# std      1431.665257    1425.810159     703.143472     511.389486
# min     10135.000000   10466.000000     109.000000       0.000000
# ...

# %%
df.isnull().sum()
# Out:
# tbl                   0
# Year                  0
# quarter               0
# citymarketid_1        0
# citymarketid_2        0
# city1                 0
# city2                 0
# airportid_1           0
# airportid_2           0
# airport_1             0
# airport_2             0
# nsmiles               0
# passengers            0
# fare                  0
# carrier_lg         1540
# large_ms           1540
# fare_lg            1540
# carrier_low        1612
# lf_ms              1612
# fare_low           1612
# Geocoded_City1    39206
# Geocoded_City2    39206
# tbl1apk               0
# dtype: int64

# %%
df.nunique()
# Out:
# tbl                    2
# Year                  31
# quarter                4
# citymarketid_1       141
# citymarketid_2       128
# city1                141
# city2                128
# airportid_1          188
# airportid_2          173
# airport_1            187
# airport_2            173
# nsmiles             1155
# passengers          3883
# fare               36323
# carrier_lg            67
# large_ms            7367
# fare_lg            37508
# carrier_low           71
# lf_ms               9687
# fare_low           32283
# Geocoded_City1       238
# Geocoded_City2       207
# tbl1apk           245955
# dtype: int64

# %%
df.sort_values(by="fare_low", ascending=False).head(10)
# Out:
#              tbl  Year  quarter  citymarketid_1  citymarketid_2  \
# 144393  Table 1a  2001        3           30977           34057
# 161918  Table 1a  2000        4           31703           32457
# 3714     Table1a  2021        4           32575           33667
# 101487  Table 1a  1998        2           31423           31703
# 110962  Table 1a  2000        3           32575           34027
# 137541  Table 1a  1998        1           33105           32575
# 97769   Table 1a  2007        2           31703           33667
# 16966   Table 1a  2011        1           30372           31703
# 9718    Table 1a  1998        2           33105           32575
# 6468    Table 1a  1999        2           31703           33316
#
#                                         city1  \
# 144393                            Chicago, IL
# 161918  New York City, NY (Metropolitan Area)
# 3714      Los Angeles, CA (Metropolitan Area)
# 101487                         Des Moines, IA
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                     Year   quarter  citymarketid_1  citymarketid_2  \
# Year            1.000000  0.006125       -0.000373       -0.007119
# quarter         0.006125  1.000000        0.000384        0.003282
# citymarketid_1 -0.000373  0.000384        1.000000        0.007237
# citymarketid_2 -0.007119  0.003282        0.007237        1.000000
# airportid_1    -0.009018  0.000650        0.526658        0.043398
# airportid_2    -0.016622  0.000613        0.061771        0.537673
# nsmiles         0.018843  0.000205        0.104284        0.091133
# passengers      0.086214  0.016498       -0.043699       -0.090974
# fare            0.151058 -0.026186        0.044420        0.014113
# large_ms        0.105231 -0.000968       -0.119061       -0.024305
# fare_lg         0.154496 -0.024517        0.036973        0.009706
# lf_ms           0.102918 -0.000426       -0.056508        0.021699
# fare_low        0.174297 -0.015940        0.033375        0.029288
#
# ...

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)

plt.rcParams['figure.figsize']=(20,20)

plt.show()

# %%
df.groupby("Year").mean(numeric_only=True)
# Out:
#        quarter  citymarketid_1  citymarketid_2   airportid_1   airportid_2  \
# Year
# 1993  2.505904    31575.736010    32180.101756  12480.171886  13337.003696
# 1994  1.000000    31585.942135    32143.593725  12500.879381  13331.543195
# 1996  2.490254    31555.924788    32167.893844  12492.203942  13300.341482
# 1997  2.498268    31563.655604    32193.592133  12504.404738  13301.188624
# 1998  2.521130    31538.335094    32191.002641  12475.521934  13259.178686
# 1999  2.487267    31527.236040    32191.117849  12399.710175  13236.741121
# 2000  2.503571    31534.155134    32198.389650  12388.577567  13242.028100
# 2001  2.484389    31541.732308    32186.273821  12396.032146  13280.969010
# 2002  2.499942    31546.439399    32203.887880  12396.651182  13262.711841
# 2003  2.510839    31556.632422    32219.691682  12408.005066  13245.751178
# 2004  2.493976    31561.098039    32213.454642  12425.707300  13244.638200
# ...

# %% [markdown]
# There's only one quarter's worth of data in 1994, and similarly for 2024. What's changed in the last 20 years?

# %%
df[df['Year']==1994]['quarter'].nunique()
# Out:
# 1

# %%
df[df['Year'].isin([1994,2024])].groupby('Year').mean(numeric_only=True)
# Out:
#       quarter  citymarketid_1  citymarketid_2   airportid_1   airportid_2  \
# Year
# 1994      1.0    31585.942135    32143.593725  12500.879381  13331.543195
# 2024      1.0    31548.964829    32178.567454  12415.200000  13185.134383
#
#           nsmiles  passengers        fare  large_ms     fare_lg     lf_ms  \
# Year
# 1994  1144.852893  162.048492  217.611944  0.646414  210.593268  0.430921
# 2024  1188.721785  390.278215  257.243160  0.712647  257.967183  0.507983
#
#         fare_low
# Year
# 1994  184.690092
# 2024  213.766819
