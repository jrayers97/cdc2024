# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_excel("Business_Dataset.xlsx",engine='openpyxl')
df
# Out:
#             tbl  Year  quarter  citymarketid_1  citymarketid_2  \
# 0       Table1a  2021        3           30135           33195
# 1       Table1a  2021        3           30135           33195
# 2       Table1a  2021        3           30140           30194
# 3       Table1a  2021        3           30140           30194
# 4       Table1a  2021        3           30140           30466
# ...         ...   ...      ...             ...             ...
# 245950  Table1a  2024        1           35412           31703
# 245951  Table1a  2024        1           35412           32467
# 245952  Table1a  2024        1           35412           32467
# 245953  Table1a  2024        1           35412           33195
# 245954  Table1a  2024        1           35412           33195
#
#                                  city1                                  city2  \
# 0       Allentown/Bethlehem/Easton, PA          Tampa, FL (Metropolitan Area)
# ...

# %%
#What are the columns? Find something interesting

df.columns
# Out:
# Index(['tbl', 'Year', 'quarter', 'citymarketid_1', 'citymarketid_2', 'city1',
#        'city2', 'airportid_1', 'airportid_2', 'airport_1', 'airport_2',
#        'nsmiles', 'passengers', 'fare', 'carrier_lg', 'large_ms', 'fare_lg',
#        'carrier_low', 'lf_ms', 'fare_low', 'Geocoded_City1', 'Geocoded_City2',
#        'tbl1apk'],
#       dtype='object')

# %%
df.filter(['city1', 'city2','fare', 'Year','carrier_lg', 'passengers' ]).sort_values(['fare'])
# Out:
#                                         city1  \
# 35810                   Dallas/Fort Worth, TX
# 42192                             Chicago, IL
# 147220                  Dallas/Fort Worth, TX
# 131112                            Chicago, IL
# 127830                  Dallas/Fort Worth, TX
# ...                                       ...
# 74780                             Chicago, IL
# 94012     Los Angeles, CA (Metropolitan Area)
# 149545                            Detroit, MI
# 90359   New York City, NY (Metropolitan Area)
# 144393                            Chicago, IL
#
#                                         city2     fare  Year carrier_lg  \
# 35810      Washington, DC (Metropolitan Area)    50.00  1997         WN
# 42192                             Wichita, KS    50.40  1997         UA
# 147220                          St. Louis, MO    50.41  1996         WN
# 131112                            Detroit, MI    50.50  1999         WN
# ...

# %%
#Note: US is US airways which merged with AA in 2015, there shouldn't be any US flights past 2015

df.filter(['carrier_lg']).value_counts()
# Out:
# carrier_lg
# WN            58999
# AA            45828
# DL            34088
# UA            29820
# US            25836
#               ...
# OH                1
# T3                1
# KS                1
# XJ                1
# ZV                1
# Name: count, Length: 67, dtype: int64

# %%
#And this checks out

df.query('carrier_lg=="US"').sort_values(['Year'])
# Out:
#              tbl  Year  quarter  citymarketid_1  citymarketid_2  \
# 66953   Table 1a  1993        2           30721           31995
# 25798   Table 1a  1993        2           30721           33495
# 161999  Table 1a  1993        3           30721           31057
# 161992  Table 1a  1993        1           30647           32457
# 87632   Table 1a  1993        1           31703           33195
# ...          ...   ...      ...             ...             ...
# 182195  Table 1a  2015        2           31995           31703
# 182217  Table 1a  2015        2           31703           35096
# 182221  Table 1a  2015        2           33667           32457
# 181924  Table 1a  2015        1           31057           32575
# 187720  Table 1a  2015        2           32575           33316
#
#                                         city1  \
# 66953          Boston, MA (Metropolitan Area)
# 25798          Boston, MA (Metropolitan Area)
# 161999         Boston, MA (Metropolitan Area)
# ...

# %%
#Here's an idea: What if we made a tool for smaller airlines to see which routes have the most amount of money to be made, relative to the amount of miles.
#Smaller airlines typically have smaller planes -> less fuel capacity, it would be interesting to see what routes would make the most money for smaller companies

#Columns to look at: Year, city1, city2, nsmiles, passengers, fare, 'carrier_lg', 'large_ms', 'fare_lg', 'carrier_low', 'lf_ms', 'fare_low', route number

# %%
df.filter(['city1', 'city2','fare_lg', 'Year','carrier_lg', 'passengers', 'nsmiles', 'carrier_low', 'fare_low' ]).sort_values(['fare_low'])
# Out:
#                                         city1  \
# 35810                   Dallas/Fort Worth, TX
# 183731  New York City, NY (Metropolitan Area)
# 230799      Cleveland, OH (Metropolitan Area)
# 42192                             Chicago, IL
# 147220                  Dallas/Fort Worth, TX
# ...                                       ...
# 244589         Boston, MA (Metropolitan Area)
# 245312  New York City, NY (Metropolitan Area)
# 245452  San Francisco, CA (Metropolitan Area)
# 245595    Los Angeles, CA (Metropolitan Area)
# 245885                            Everett, WA
#
#                                         city2  fare_lg  Year carrier_lg  \
# 35810      Washington, DC (Metropolitan Area)    50.00  1997         WN
# 183731     Washington, DC (Metropolitan Area)   399.80  2015         US
# 230799          Miami, FL (Metropolitan Area)   261.43  2022         AA
# 42192                             Wichita, KS    50.40  1997         UA
# ...
